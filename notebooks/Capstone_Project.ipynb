# %%
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
directory = "C:/Users/koppa/Downloads/archive"
joined_list = glob.glob(os.path.join(directory, "*.csv"))
data = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# %%
# Save the concatenated DataFrame to a new CSV file
data.to_csv("combined_csv3.csv", index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17239 entries, 0 to 17238
# Columns: 128 entries, iso_code to wind_energy_per_capita
# dtypes: float64(125), int64(1), object(2)
# memory usage: 16.8+ MB

# %%
data.head()
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_consumption  \
# ...

# %%
data.describe()
# Out:
#                year  coal_prod_change_pct  coal_prod_change_twh  \
# count  17239.000000           7152.000000          13589.000000
# mean    1973.609722             23.968662              9.621462
# std       34.727666            725.148859            149.031801
# min     1900.000000           -100.000000          -2366.470000
# 25%     1946.000000             -5.226250              0.000000
# 50%     1983.000000              2.030000              0.000000
# 75%     2002.000000              9.994500              0.163000
# max     2021.000000          44965.754000           3057.952000
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# count         5.074000e+03          9491.000000          6474.000000
# mean          1.841334e+14            14.152412            20.067887
# std           1.311620e+16            92.682368           354.470689
# min          -1.000000e+02         -1225.490000          -100.000000
# ...
